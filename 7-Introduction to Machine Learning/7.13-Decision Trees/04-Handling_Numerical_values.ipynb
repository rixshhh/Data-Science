# %% [markdown]
# # Handling Numerical Values in Decision Trees
#
# Decision trees can handle numerical (continuous) features very effectively.
# Unlike categorical values (where each category can be a split), numerical values require finding a threshold to split the data.

# %% [markdown]
# ## How Decision Trees Handle Numerical Features

# %% [markdown]
# ### We have data Initially
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 3
#
# ![image.png](attachment:image.png)
#
# For Every Rating for User_rating , We split the entire dataset into Two parts.

# %% [markdown]
# ### Step 4
#
# ![image.png](attachment:image.png)
#
# E : Entropy
#
# WE : Weighted Entropy
#
# IG : Information Gain

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
