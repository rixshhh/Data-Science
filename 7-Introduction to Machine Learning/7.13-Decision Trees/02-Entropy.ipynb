# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the most layman term, **Entropy** is nothing but the **measure of disorder**. Or we can also call it measure of **Purity / Impurity**.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dataset 1 has higher Entropy , Because here it's very difficult to predict.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Example
#
# ### Calculating Entropy for 2 Class Problem
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Calculating Entropy for 3 Class Problem
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Observation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Information Gain
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Formula for Information Gain
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
